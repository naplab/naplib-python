# %%
import numpy as np
import matplotlib.pyplot as plt

import naplib as nl

# %%
filepath = '../out_structs/out_struct_sample.mat'
out = nl.io.import_outstruct(filepath)
print(f'This out struct has data for {len(out)} trials')
# Out:
# This out struct has data for 18 trials

# %%
# corresponding STRFlab strfs
from hdf5storage import loadmat
strflab = loadmat('../out_structs/STRFLab_predictions_LIJ120clean.mat')
strflab['strf_cell'] = strflab['strf_cell'].squeeze()
strflab['strf_preds'] = strflab['strf_preds'].squeeze()
strflab['strf_corrs'] = strflab['strf_corrs'].squeeze()

# %%
# This out struct contains the fields 'aud' and 'resp', which give the stimulus and neural responses
print(f"aud stimulus shape for first trial : {out[0]['aud'].shape}")
print(f"response shape for first trial : {out[0]['resp'].shape}")
# Out:
# aud stimulus shape for first trial : (6047, 23)
# response shape for first trial : (6047, 30)

# %%
# Let's look at the first 5 seconds more closely

fig, axes = plt.subplots(2,1,figsize=(8,5), sharex=True)
axes[0].imshow(out[0]['aud'][:500].T, origin='lower', aspect=4)

axes[1].plot(out[0]['resp'][:500])
plt.show()

# %% [markdown]
# ## Fit STRFs
#
# Fit STRF models that have a receptive field of 400 ms in the past

# %%
tmin = 0 # receptive field begins at time=0
tmax = 0.4 # receptive field ends at a lag of 0.4 seconds
sfreq = 100 # sampling frequency of data

strf_model = nl.encoding.TRF(tmin, tmax, sfreq)

# %%
# first, we normalize the responses
out['resp'] = nl.preprocessing.normalize(outstruct=out, data='resp')

# %%
# train model on the first 16 trials 
out_train = out[:16]
out_test = out[16:]

# %% [markdown]
# ### Fit STRFs with default model params
#
# - 'Ridge' regularization, default set of alphas

# %%
# Now, fit the model to the training data. This model with contain
# 30 STRFs, one for each output channel in resp

strf_model.fit(outstruct=out_train, X='aud', y='resp')
# Out:
# Fitting model for output variable 0...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2542
# alpha=1.00e+03 : 0.2542
# alpha=1.00e+04 : 0.2547
# alpha=1.00e+05 : 0.2576
# alpha=1.00e+06 : 0.2676
# alpha=1.00e+07 : 0.2829
# alpha=1.00e+08 : 0.2826
# alpha=1.00e+09 : 0.2692
# chose alpha=1.00e+07
#
# Fitting model for output variable 1...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2738
# alpha=1.00e+03 : 0.2738
# alpha=1.00e+04 : 0.2743
# alpha=1.00e+05 : 0.2767
# alpha=1.00e+06 : 0.2859
# alpha=1.00e+07 : 0.3050
# alpha=1.00e+08 : 0.2945
# alpha=1.00e+09 : 0.2706
# chose alpha=1.00e+07
#
# Fitting model for output variable 2...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2479
# alpha=1.00e+03 : 0.2480
# alpha=1.00e+04 : 0.2483
# alpha=1.00e+05 : 0.2497
# alpha=1.00e+06 : 0.2550
# alpha=1.00e+07 : 0.2698
# alpha=1.00e+08 : 0.2771
# alpha=1.00e+09 : 0.2746
# chose alpha=1.00e+08
#
# Fitting model for output variable 3...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3637
# alpha=1.00e+03 : 0.3637
# alpha=1.00e+04 : 0.3640
# alpha=1.00e+05 : 0.3656
# alpha=1.00e+06 : 0.3721
# alpha=1.00e+07 : 0.3749
# alpha=1.00e+08 : 0.3493
# alpha=1.00e+09 : 0.3325
# chose alpha=1.00e+07
#
# Fitting model for output variable 4...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1154
# alpha=1.00e+03 : 0.1155
# alpha=1.00e+04 : 0.1160
# alpha=1.00e+05 : 0.1191
# alpha=1.00e+06 : 0.1309
# alpha=1.00e+07 : 0.1454
# alpha=1.00e+08 : 0.1408
# alpha=1.00e+09 : 0.1336
# chose alpha=1.00e+07
#
# Fitting model for output variable 5...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3666
# alpha=1.00e+03 : 0.3667
# alpha=1.00e+04 : 0.3670
# alpha=1.00e+05 : 0.3692
# alpha=1.00e+06 : 0.3779
# alpha=1.00e+07 : 0.3977
# alpha=1.00e+08 : 0.3992
# alpha=1.00e+09 : 0.3709
# chose alpha=1.00e+08
#
# Fitting model for output variable 6...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3375
# alpha=1.00e+03 : 0.3375
# alpha=1.00e+04 : 0.3378
# alpha=1.00e+05 : 0.3395
# alpha=1.00e+06 : 0.3470
# alpha=1.00e+07 : 0.3634
# alpha=1.00e+08 : 0.3654
# alpha=1.00e+09 : 0.3533
# chose alpha=1.00e+08
#
# Fitting model for output variable 7...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4125
# alpha=1.00e+03 : 0.4126
# alpha=1.00e+04 : 0.4129
# alpha=1.00e+05 : 0.4145
# alpha=1.00e+06 : 0.4208
# alpha=1.00e+07 : 0.4276
# alpha=1.00e+08 : 0.4224
# alpha=1.00e+09 : 0.4141
# chose alpha=1.00e+07
#
# Fitting model for output variable 8...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4992
# alpha=1.00e+03 : 0.4992
# alpha=1.00e+04 : 0.4994
# alpha=1.00e+05 : 0.5008
# alpha=1.00e+06 : 0.5054
# alpha=1.00e+07 : 0.5070
# alpha=1.00e+08 : 0.4971
# alpha=1.00e+09 : 0.4817
# chose alpha=1.00e+07
#
# Fitting model for output variable 9...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3077
# alpha=1.00e+03 : 0.3077
# alpha=1.00e+04 : 0.3082
# alpha=1.00e+05 : 0.3116
# alpha=1.00e+06 : 0.3237
# alpha=1.00e+07 : 0.3412
# alpha=1.00e+08 : 0.3372
# alpha=1.00e+09 : 0.3052
# chose alpha=1.00e+07
#
# Fitting model for output variable 10...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1250
# alpha=1.00e+03 : 0.1251
# alpha=1.00e+04 : 0.1257
# alpha=1.00e+05 : 0.1292
# alpha=1.00e+06 : 0.1431
# alpha=1.00e+07 : 0.1816
# alpha=1.00e+08 : 0.1953
# alpha=1.00e+09 : 0.1931
# chose alpha=1.00e+08
#
# Fitting model for output variable 11...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2639
# alpha=1.00e+03 : 0.2639
# alpha=1.00e+04 : 0.2643
# alpha=1.00e+05 : 0.2663
# alpha=1.00e+06 : 0.2741
# alpha=1.00e+07 : 0.2881
# alpha=1.00e+08 : 0.2936
# alpha=1.00e+09 : 0.2902
# chose alpha=1.00e+08
#
# Fitting model for output variable 12...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2360
# alpha=1.00e+03 : 0.2360
# alpha=1.00e+04 : 0.2365
# alpha=1.00e+05 : 0.2396
# alpha=1.00e+06 : 0.2530
# alpha=1.00e+07 : 0.2731
# alpha=1.00e+08 : 0.2766
# alpha=1.00e+09 : 0.2732
# chose alpha=1.00e+08
#
# Fitting model for output variable 13...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3749
# alpha=1.00e+03 : 0.3749
# alpha=1.00e+04 : 0.3753
# alpha=1.00e+05 : 0.3776
# alpha=1.00e+06 : 0.3855
# alpha=1.00e+07 : 0.3938
# alpha=1.00e+08 : 0.3950
# alpha=1.00e+09 : 0.3840
# chose alpha=1.00e+08
#
# Fitting model for output variable 14...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3292
# alpha=1.00e+03 : 0.3292
# alpha=1.00e+04 : 0.3296
# alpha=1.00e+05 : 0.3318
# alpha=1.00e+06 : 0.3398
# alpha=1.00e+07 : 0.3516
# alpha=1.00e+08 : 0.3549
# alpha=1.00e+09 : 0.3487
# chose alpha=1.00e+08
#
# Fitting model for output variable 15...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3290
# alpha=1.00e+03 : 0.3290
# alpha=1.00e+04 : 0.3294
# alpha=1.00e+05 : 0.3320
# alpha=1.00e+06 : 0.3403
# alpha=1.00e+07 : 0.3515
# alpha=1.00e+08 : 0.3530
# alpha=1.00e+09 : 0.3472
# chose alpha=1.00e+08
#
# Fitting model for output variable 16...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4488
# alpha=1.00e+03 : 0.4488
# alpha=1.00e+04 : 0.4491
# alpha=1.00e+05 : 0.4507
# alpha=1.00e+06 : 0.4556
# alpha=1.00e+07 : 0.4597
# alpha=1.00e+08 : 0.4542
# alpha=1.00e+09 : 0.4396
# chose alpha=1.00e+07
#
# Fitting model for output variable 17...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4027
# alpha=1.00e+03 : 0.4027
# alpha=1.00e+04 : 0.4032
# alpha=1.00e+05 : 0.4057
# alpha=1.00e+06 : 0.4136
# alpha=1.00e+07 : 0.4186
# alpha=1.00e+08 : 0.4069
# alpha=1.00e+09 : 0.3605
# chose alpha=1.00e+07
#
# Fitting model for output variable 18...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3125
# alpha=1.00e+03 : 0.3126
# alpha=1.00e+04 : 0.3130
# alpha=1.00e+05 : 0.3157
# alpha=1.00e+06 : 0.3247
# alpha=1.00e+07 : 0.3381
# alpha=1.00e+08 : 0.3440
# alpha=1.00e+09 : 0.3409
# chose alpha=1.00e+08
#
# Fitting model for output variable 19...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4804
# alpha=1.00e+03 : 0.4804
# alpha=1.00e+04 : 0.4807
# alpha=1.00e+05 : 0.4824
# alpha=1.00e+06 : 0.4870
# alpha=1.00e+07 : 0.4906
# alpha=1.00e+08 : 0.4823
# alpha=1.00e+09 : 0.4633
# chose alpha=1.00e+07
#
# Fitting model for output variable 20...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.5566
# alpha=1.00e+03 : 0.5567
# alpha=1.00e+04 : 0.5569
# alpha=1.00e+05 : 0.5583
# alpha=1.00e+06 : 0.5630
# alpha=1.00e+07 : 0.5663
# alpha=1.00e+08 : 0.5596
# alpha=1.00e+09 : 0.5450
# chose alpha=1.00e+07
#
# Fitting model for output variable 21...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.6066
# alpha=1.00e+03 : 0.6067
# alpha=1.00e+04 : 0.6069
# alpha=1.00e+05 : 0.6084
# alpha=1.00e+06 : 0.6130
# alpha=1.00e+07 : 0.6139
# alpha=1.00e+08 : 0.6009
# alpha=1.00e+09 : 0.5745
# chose alpha=1.00e+07
#
# Fitting model for output variable 22...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.5332
# alpha=1.00e+03 : 0.5333
# alpha=1.00e+04 : 0.5336
# alpha=1.00e+05 : 0.5356
# alpha=1.00e+06 : 0.5415
# alpha=1.00e+07 : 0.5416
# alpha=1.00e+08 : 0.5209
# alpha=1.00e+09 : 0.4836
# chose alpha=1.00e+07
#
# Fitting model for output variable 23...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2511
# alpha=1.00e+03 : 0.2512
# alpha=1.00e+04 : 0.2517
# alpha=1.00e+05 : 0.2551
# alpha=1.00e+06 : 0.2671
# alpha=1.00e+07 : 0.2753
# alpha=1.00e+08 : 0.2572
# alpha=1.00e+09 : 0.2380
# chose alpha=1.00e+07
#
# Fitting model for output variable 24...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1208
# alpha=1.00e+03 : 0.1209
# alpha=1.00e+04 : 0.1211
# alpha=1.00e+05 : 0.1225
# alpha=1.00e+06 : 0.1246
# alpha=1.00e+07 : 0.1108
# alpha=1.00e+08 : 0.0740
# alpha=1.00e+09 : 0.0416
# chose alpha=1.00e+06
#
# Fitting model for output variable 25...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1899
# alpha=1.00e+03 : 0.1900
# alpha=1.00e+04 : 0.1905
# alpha=1.00e+05 : 0.1938
# alpha=1.00e+06 : 0.2064
# alpha=1.00e+07 : 0.2161
# alpha=1.00e+08 : 0.2155
# alpha=1.00e+09 : 0.2159
# chose alpha=1.00e+07
# Fitting model for output variable 26...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.0869
# alpha=1.00e+03 : 0.0870
# alpha=1.00e+04 : 0.0874
# alpha=1.00e+05 : 0.0898
# alpha=1.00e+06 : 0.0980
# alpha=1.00e+07 : 0.1086
# alpha=1.00e+08 : 0.1159
# alpha=1.00e+09 : 0.1125
# chose alpha=1.00e+08
#
# Fitting model for output variable 27...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1271
# alpha=1.00e+03 : 0.1271
# alpha=1.00e+04 : 0.1277
# alpha=1.00e+05 : 0.1312
# alpha=1.00e+06 : 0.1438
# alpha=1.00e+07 : 0.1637
# alpha=1.00e+08 : 0.1754
# alpha=1.00e+09 : 0.1715
# chose alpha=1.00e+08
#
# Fitting model for output variable 28...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1690
# alpha=1.00e+03 : 0.1691
# alpha=1.00e+04 : 0.1696
# alpha=1.00e+05 : 0.1731
# alpha=1.00e+06 : 0.1862
# alpha=1.00e+07 : 0.2084
# alpha=1.00e+08 : 0.2173
# alpha=1.00e+09 : 0.2092
# chose alpha=1.00e+08
#
# Fitting model for output variable 29...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1323
# alpha=1.00e+03 : 0.1324
# alpha=1.00e+04 : 0.1329
# alpha=1.00e+05 : 0.1365
# alpha=1.00e+06 : 0.1503
# alpha=1.00e+07 : 0.1810
# alpha=1.00e+08 : 0.1998
# alpha=1.00e+09 : 0.1935
# chose alpha=1.00e+08
# TRF(alpha=[100.0, 1000.0, 10000.0, 100000.0, 1000000.0, 10000000.0, 100000000.0,
#            1000000000.0],
#     sfreq=100.0, tmax=0.4, tmin=0)

# %% [markdown]
# ### Fit STRFs with different regularization
#
# - 'Laplacian' regularization, modified range of alphas

# %%
# We can also change things like the regularization type, and even the range of
# regularization alphas for the cross-validation procedure. By default, the
# model is fit with 'ridge' regularization

strf_model_2 = nl.encoding.TRF(tmin, tmax, sfreq, reg_type='laplacian', alpha=np.logspace(2,10,8))
strf_model_2.fit(outstruct=out_train, X='aud', y='resp')
# Out:
# Fitting model for output variable 0...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2531
# alpha=1.39e+03 : 0.2534
# alpha=1.93e+04 : 0.2555
# alpha=2.68e+05 : 0.2639
# alpha=3.73e+06 : 0.2791
# alpha=5.18e+07 : 0.2829
# alpha=7.20e+08 : 0.2752
# alpha=1.00e+10 : 0.2653
# chose alpha=5.18e+07
#
# Fitting model for output variable 1...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2730
# alpha=1.39e+03 : 0.2733
# alpha=1.93e+04 : 0.2748
# alpha=2.68e+05 : 0.2805
# alpha=3.73e+06 : 0.3000
# alpha=5.18e+07 : 0.2963
# alpha=7.20e+08 : 0.2747
# alpha=1.00e+10 : 0.2680
# chose alpha=3.73e+06
#
# Fitting model for output variable 2...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2472
# alpha=1.39e+03 : 0.2473
# alpha=1.93e+04 : 0.2483
# alpha=2.68e+05 : 0.2515
# alpha=3.73e+06 : 0.2649
# alpha=5.18e+07 : 0.2754
# alpha=7.20e+08 : 0.2753
# alpha=1.00e+10 : 0.2736
# chose alpha=5.18e+07
#
# Fitting model for output variable 3...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3632
# alpha=1.39e+03 : 0.3634
# alpha=1.93e+04 : 0.3645
# alpha=2.68e+05 : 0.3700
# alpha=3.73e+06 : 0.3705
# alpha=5.18e+07 : 0.3428
# alpha=7.20e+08 : 0.3306
# alpha=1.00e+10 : 0.3283
# chose alpha=3.73e+06
#
# Fitting model for output variable 4...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1151
# alpha=1.39e+03 : 0.1154
# alpha=1.93e+04 : 0.1177
# alpha=2.68e+05 : 0.1280
# alpha=3.73e+06 : 0.1422
# alpha=5.18e+07 : 0.1398
# alpha=7.20e+08 : 0.1362
# alpha=1.00e+10 : 0.1314
# chose alpha=3.73e+06
#
# Fitting model for output variable 5...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3654
# alpha=1.39e+03 : 0.3656
# alpha=1.93e+04 : 0.3670
# alpha=2.68e+05 : 0.3731
# alpha=3.73e+06 : 0.3913
# alpha=5.18e+07 : 0.4014
# alpha=7.20e+08 : 0.3924
# alpha=1.00e+10 : 0.3647
# chose alpha=5.18e+07
#
# Fitting model for output variable 6...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3361
# alpha=1.39e+03 : 0.3362
# alpha=1.93e+04 : 0.3372
# alpha=2.68e+05 : 0.3423
# alpha=3.73e+06 : 0.3596
# alpha=5.18e+07 : 0.3662
# alpha=7.20e+08 : 0.3606
# alpha=1.00e+10 : 0.3531
# chose alpha=5.18e+07
#
# Fitting model for output variable 7...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4112
# alpha=1.39e+03 : 0.4114
# alpha=1.93e+04 : 0.4125
# alpha=2.68e+05 : 0.4179
# alpha=3.73e+06 : 0.4242
# alpha=5.18e+07 : 0.4209
# alpha=7.20e+08 : 0.4178
# alpha=1.00e+10 : 0.4134
# chose alpha=3.73e+06
#
# Fitting model for output variable 8...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4978
# alpha=1.39e+03 : 0.4979
# alpha=1.93e+04 : 0.4988
# alpha=2.68e+05 : 0.5027
# alpha=3.73e+06 : 0.5047
# alpha=5.18e+07 : 0.4966
# alpha=7.20e+08 : 0.4893
# alpha=1.00e+10 : 0.4779
# chose alpha=3.73e+06
#
# Fitting model for output variable 9...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3063
# alpha=1.39e+03 : 0.3066
# alpha=1.93e+04 : 0.3088
# alpha=2.68e+05 : 0.3175
# alpha=3.73e+06 : 0.3298
# alpha=5.18e+07 : 0.3412
# alpha=7.20e+08 : 0.3289
# alpha=1.00e+10 : 0.3008
# chose alpha=5.18e+07
#
# Fitting model for output variable 10...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1248
# alpha=1.39e+03 : 0.1252
# alpha=1.93e+04 : 0.1278
# alpha=2.68e+05 : 0.1390
# alpha=3.73e+06 : 0.1753
# alpha=5.18e+07 : 0.1916
# alpha=7.20e+08 : 0.1931
# alpha=1.00e+10 : 0.1931
# chose alpha=1.00e+10
#
# Fitting model for output variable 11...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2637
# alpha=1.39e+03 : 0.2639
# alpha=1.93e+04 : 0.2652
# alpha=2.68e+05 : 0.2714
# alpha=3.73e+06 : 0.2842
# alpha=5.18e+07 : 0.2919
# alpha=7.20e+08 : 0.2931
# alpha=1.00e+10 : 0.2903
# chose alpha=7.20e+08
#
# Fitting model for output variable 12...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2356
# alpha=1.39e+03 : 0.2358
# alpha=1.93e+04 : 0.2380
# alpha=2.68e+05 : 0.2495
# alpha=3.73e+06 : 0.2680
# alpha=5.18e+07 : 0.2730
# alpha=7.20e+08 : 0.2749
# alpha=1.00e+10 : 0.2737
# chose alpha=7.20e+08
#
# Fitting model for output variable 13...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3736
# alpha=1.39e+03 : 0.3738
# alpha=1.93e+04 : 0.3755
# alpha=2.68e+05 : 0.3827
# alpha=3.73e+06 : 0.3904
# alpha=5.18e+07 : 0.3944
# alpha=7.20e+08 : 0.3945
# alpha=1.00e+10 : 0.3834
# chose alpha=7.20e+08
#
# Fitting model for output variable 14...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3280
# alpha=1.39e+03 : 0.3282
# alpha=1.93e+04 : 0.3298
# alpha=2.68e+05 : 0.3364
# alpha=3.73e+06 : 0.3473
# alpha=5.18e+07 : 0.3533
# alpha=7.20e+08 : 0.3531
# alpha=1.00e+10 : 0.3469
# chose alpha=5.18e+07
#
# Fitting model for output variable 15...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3276
# alpha=1.39e+03 : 0.3279
# alpha=1.93e+04 : 0.3297
# alpha=2.68e+05 : 0.3366
# alpha=3.73e+06 : 0.3480
# alpha=5.18e+07 : 0.3514
# alpha=7.20e+08 : 0.3485
# alpha=1.00e+10 : 0.3446
# chose alpha=5.18e+07
#
# Fitting model for output variable 16...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4472
# alpha=1.39e+03 : 0.4474
# alpha=1.93e+04 : 0.4486
# alpha=2.68e+05 : 0.4527
# alpha=3.73e+06 : 0.4574
# alpha=5.18e+07 : 0.4541
# alpha=7.20e+08 : 0.4467
# alpha=1.00e+10 : 0.4355
# chose alpha=3.73e+06
#
# Fitting model for output variable 17...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4017
# alpha=1.39e+03 : 0.4020
# alpha=1.93e+04 : 0.4038
# alpha=2.68e+05 : 0.4111
# alpha=3.73e+06 : 0.4169
# alpha=5.18e+07 : 0.4125
# alpha=7.20e+08 : 0.4010
# alpha=1.00e+10 : 0.3506
# chose alpha=3.73e+06
#
# Fitting model for output variable 18...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.3113
# alpha=1.39e+03 : 0.3116
# alpha=1.93e+04 : 0.3135
# alpha=2.68e+05 : 0.3212
# alpha=3.73e+06 : 0.3336
# alpha=5.18e+07 : 0.3428
# alpha=7.20e+08 : 0.3431
# alpha=1.00e+10 : 0.3401
# chose alpha=7.20e+08
#
# Fitting model for output variable 19...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.4790
# alpha=1.39e+03 : 0.4792
# alpha=1.93e+04 : 0.4804
# alpha=2.68e+05 : 0.4840
# alpha=3.73e+06 : 0.4883
# alpha=5.18e+07 : 0.4870
# alpha=7.20e+08 : 0.4761
# alpha=1.00e+10 : 0.4620
# chose alpha=3.73e+06
#
# Fitting model for output variable 20...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.5549
# alpha=1.39e+03 : 0.5550
# alpha=1.93e+04 : 0.5560
# alpha=2.68e+05 : 0.5600
# alpha=3.73e+06 : 0.5639
# alpha=5.18e+07 : 0.5601
# alpha=7.20e+08 : 0.5552
# alpha=1.00e+10 : 0.5460
# chose alpha=3.73e+06
#
# Fitting model for output variable 21...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.6051
# alpha=1.39e+03 : 0.6052
# alpha=1.93e+04 : 0.6063
# alpha=2.68e+05 : 0.6106
# alpha=3.73e+06 : 0.6126
# alpha=5.18e+07 : 0.6033
# alpha=7.20e+08 : 0.5950
# alpha=1.00e+10 : 0.5732
# chose alpha=3.73e+06
#
# Fitting model for output variable 22...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.5320
# alpha=1.39e+03 : 0.5321
# alpha=1.93e+04 : 0.5336
# alpha=2.68e+05 : 0.5392
# alpha=3.73e+06 : 0.5409
# alpha=5.18e+07 : 0.5264
# alpha=7.20e+08 : 0.5132
# alpha=1.00e+10 : 0.4814
# chose alpha=3.73e+06
#
# Fitting model for output variable 23...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.2505
# alpha=1.39e+03 : 0.2508
# alpha=1.93e+04 : 0.2532
# alpha=2.68e+05 : 0.2633
# alpha=3.73e+06 : 0.2707
# alpha=5.18e+07 : 0.2549
# alpha=7.20e+08 : 0.2478
# alpha=1.00e+10 : 0.2364
# chose alpha=3.73e+06
#
# Fitting model for output variable 24...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1210
# alpha=1.39e+03 : 0.1212
# alpha=1.93e+04 : 0.1222
# alpha=2.68e+05 : 0.1241
# alpha=3.73e+06 : 0.1099
# alpha=5.18e+07 : 0.0777
# alpha=7.20e+08 : 0.0620
# alpha=1.00e+10 : 0.0334
# chose alpha=2.68e+05
#
# Fitting model for output variable 25...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1897
# alpha=1.39e+03 : 0.1900
# alpha=1.93e+04 : 0.1924
# alpha=2.68e+05 : 0.2044
# alpha=3.73e+06 : 0.2126
# alpha=5.18e+07 : 0.2100
# alpha=7.20e+08 : 0.2119
# alpha=1.00e+10 : 0.2148
# chose alpha=1.00e+10
# Fitting model for output variable 26...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.0855
# alpha=1.39e+03 : 0.0858
# alpha=1.93e+04 : 0.0877
# alpha=2.68e+05 : 0.0955
# alpha=3.73e+06 : 0.1031
# alpha=5.18e+07 : 0.1112
# alpha=7.20e+08 : 0.1153
# alpha=1.00e+10 : 0.1106
# chose alpha=7.20e+08
#
# Fitting model for output variable 27...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1246
# alpha=1.39e+03 : 0.1249
# alpha=1.93e+04 : 0.1276
# alpha=2.68e+05 : 0.1392
# alpha=3.73e+06 : 0.1561
# alpha=5.18e+07 : 0.1716
# alpha=7.20e+08 : 0.1743
# alpha=1.00e+10 : 0.1700
# chose alpha=7.20e+08
#
# Fitting model for output variable 28...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1667
# alpha=1.39e+03 : 0.1670
# alpha=1.93e+04 : 0.1697
# alpha=2.68e+05 : 0.1812
# alpha=3.73e+06 : 0.2014
# alpha=5.18e+07 : 0.2153
# alpha=7.20e+08 : 0.2155
# alpha=1.00e+10 : 0.2082
# chose alpha=7.20e+08
#
# Fitting model for output variable 29...
# Running cross-validation on alphas...
# Cross-validation scores:
# alpha=1.00e+02 : 0.1302
# alpha=1.39e+03 : 0.1305
# alpha=1.93e+04 : 0.1332
# alpha=2.68e+05 : 0.1451
# alpha=3.73e+06 : 0.1724
# alpha=5.18e+07 : 0.1954
# alpha=7.20e+08 : 0.2001
# alpha=1.00e+10 : 0.1931
# chose alpha=7.20e+08
# TRF(alpha=array([1.00000000e+02, 1.38949549e+03, 1.93069773e+04, 2.68269580e+05,
#        3.72759372e+06, 5.17947468e+07, 7.19685673e+08, 1.00000000e+10]),
#     reg_type='laplacian', sfreq=100.0, tmax=0.4, tmin=0)

# %% [markdown]
# ## Analyze the STRFs

# %%
# compute correlation scores for the withheld test data

scores = strf_model.score(outstruct=out_test, X='aud', y='resp')
scores_2 = strf_model_2.score(outstruct=out_test, X='aud', y='resp')

# %%
# compare the scores from each model's predictions

fig, axes = plt.subplots(1,3,figsize=(10,3), sharex=True)
axes[0].hist(scores, 15)
axes[0].set_xlabel('Prediction correlation')
axes[0].set_title('Ridge Model Scores')
axes[1].hist(scores_2, 15)
axes[1].set_xlabel('Prediction correlation')
axes[1].set_title('Laplacian Model Scores')
axes[2].scatter(scores, scores_2)
axes[2].set_xlabel('Ridge model correlation')
axes[2].set_ylabel('Laplacian model correlation')
axes[2].plot([0,0.75],[0,0.75],'r--')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(10,3), sharex=True)
axes[0].hist(strflab['strf_corrs'], 15)
axes[0].set_xlabel('Prediction correlation')
axes[0].set_title('STRFLab Scores')
axes[1].hist(scores_2, 15)
axes[1].set_xlabel('Prediction correlation')
axes[1].set_title('Laplacian Model Scores')
axes[2].scatter(strflab['strf_corrs'], scores_2)
axes[2].set_xlabel('STRFLab correlation')
axes[2].set_ylabel('Laplacian model correlation')
axes[2].plot([0,0.75],[0,0.75],'r--')
plt.tight_layout()
plt.show()

# %%
# we can access the STRF weights through the .coef_ attribute of the model
coef_ridge = strf_model.coef_
coef_laplacian = strf_model_2.coef_

print(f'STRF shape (num_outputs, frequency, lag) = {coef_ridge.shape}')
# Out:
# STRF shape (num_outputs, frequency, lag) = (30, 23, 40)

# %% [markdown]
# ### Visualize the STRF for each electrode
#
# We can see that the Laplacian-regularized model gives a smoother STRF

# %%
scores
# Out:
# array([0.39287119, 0.39654417, 0.36369798, 0.46032105, 0.24190796,
#        0.44699336, 0.40338038, 0.49882983, 0.55886392, 0.34187401,
#        0.24152288, 0.367628  , 0.34094385, 0.51547184, 0.44950021,
#        0.32924177, 0.46661251, 0.48751954, 0.41405977, 0.54837384,
#        0.59858052, 0.62231218, 0.54179473, 0.2280541 , 0.03528106,
#        0.27093593, 0.15199215, 0.24245408, 0.30223146, 0.26455634])

# %%
# Now, visualize the STRF weights for each electrode and for each model
from naplib.visualization import imSTRF

freqs = np.array([171.875, 250., 328.125, 421.875, 531.25, 640.625, 750., 890.625,
                  1031.25, 1171.875, 1343.75, 1531.25, 1734.375, 1937.5, 2187.5,
                  2437.5, 2718.75, 3015.625, 3359.375, 3718.75, 4109.375, 4531.25, 5000])

for elec, (model_1_coef, model_2_coef, score_model_1, score_model_2) in enumerate(zip(coef_ridge, coef_laplacian, scores, scores_2)):
    fig, axes = plt.subplots(1,3,figsize=(6,2.5))
    imSTRF(strflab['strf_cell'][elec].squeeze(), tmin=tmin, tmax=tmax, freqs=freqs, ax=axes[0])
    axes[0].set_title('STRFLab, corr={:2.3f}'.format(strflab['strf_corrs'][elec].squeeze()))
    
    imSTRF(model_1_coef, tmin=tmin, tmax=tmax, freqs=freqs, ax=axes[1])
    axes[1].set_title('Ridge, corr={:2.3f}'.format(score_model_1))
    imSTRF(model_2_coef, tmin=tmin, tmax=tmax, freqs=freqs, ax=axes[2])
    axes[2].set_title('Laplacian, corr={:2.3f}'.format(score_model_2))
    fig.suptitle(f'Electrode {elec}')
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ### Compute and Plot STRF Predictions
#
# We see that the two STRF models have nearly identical predictions for most electrodes

# %%
predictions = strf_model.predict(outstruct=out_test, X='aud') # this is a list of the same length as out_test
predictions_2 = strf_model_2.predict(outstruct=out_test, X='aud')

# shapes of predictions for each trial 
print([x.shape for x in predictions])
# Out:
# [(2829, 30), (2836, 30)]

# %%
# plot the predictions for the first 10 seconds of the second-to-last trial for each electrode


max_time = 1000

for elec in range(predictions[0].shape[1]):

    plt.figure(figsize=(12,3))
    plt.plot(out_test['resp'][-2][:max_time,elec], label='neural')
    plt.plot(strflab['strf_preds'][elec].squeeze()[-2].squeeze()[:max_time], label='STRFLab pred, corr={:2.2f}'.format(strflab['strf_corrs'][elec].squeeze()))
    plt.plot(predictions[-2][:max_time,elec], label='ridge pred, corr={:2.2f}'.format(scores[elec]))
    plt.plot(predictions_2[-2][:max_time,elec], label='laplacian pred, corr={:2.2f}'.format(scores[elec]))
#     plt.xticks([0, 500, 1000], ['0', '5', '10'])
    plt.xlabel('Time (s)')
    plt.legend()
    plt.title(f'Electrode {elec}')
    plt.show()
